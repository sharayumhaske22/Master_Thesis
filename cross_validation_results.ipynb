# %%
# =========================================================
# FINAL MANUAL ANALYSIS CODE
# Original Model vs 5-Fold Cross Validation
# Outputs ONLY TWO TABLES
# =========================================================

import pandas as pd
import numpy as np

# =========================================================
# 1. MANUALLY ENTER ORIGINAL MODEL OVERALL TEST RESULTS
# =========================================================
# Replace the 0.0000 values with your original model test results


	

original_overall = {
    "test_loss": 0.58406353,
    "test_f1_macro": 0.378347188,
    "test_f1_micro": 0.449814126,
    "test_pearson_mean": 0.451527466
}


# =========================================================
# 2. MANUALLY ENTER 5-FOLD OVERALL TEST RESULTS
# =========================================================
# Replace all 0.0000 values with the final test results from each fold

fold_overall_results = [
    {
        "fold": 1,
        "test_loss": 0.568502963,
        "test_f1_macro": 0.266455062,
        "test_f1_micro": 0.378527185,
        "test_pearson_mean": 0.445922304
    },
    {
        "fold": 2,
        "test_loss": 0.558476627,
        "test_f1_macro": 0.354744756,
        "test_f1_micro": 0.444587629,
        "test_pearson_mean": 0.452482534
    },
    {
        "fold": 3,
        "test_loss": 0.534285128,
        "test_f1_macro": 0.387679934,
        "test_f1_micro": 0.44892648,
        "test_pearson_mean": 0.463207203
    },
    {
        "fold": 4,
        "test_loss": 0.571601629,
        "test_f1_macro": 0.322453426,
        "test_f1_micro": 0.404378622,
        "test_pearson_mean": 0.439231072
    } ,
    {
        "fold": 5,
        "test_loss": 0.572902858,
        "test_f1_macro": 0.372063791,
        "test_f1_micro": 0.433044637,
        "test_pearson_mean": 0.441771168
    }
    
]


# =========================================================
# 3. MANUALLY ENTER ORIGINAL MODEL CLASSWISE TEST RESULTS
# =========================================================
# Replace precision, recall, f1_score, support with original model values


original_classwise_results = [
    {"class": "anger_1", "precision": 0.266666667, "recall": 0.111111111, "f1_score": 0.156862745, "support": 36},
    {"class": "anger_2", "precision": 0.333333333, "recall": 0.2, "f1_score": 0.25, "support": 15},
    {"class": "anger_3", "precision": 0, "recall": 0, "f1_score": 0, "support": 9},

    {"class": "fear_1", "precision": 0.435582822, "recall": 0.446540881, "f1_score": 0.440993789, "support": 159},
    {"class": "fear_2", "precision": 0.427480916, "recall": 0.565656566, "f1_score": 0.486956522, "support": 99},
    {"class": "fear_3", "precision": 0.613636364, "recall": 0.54, "f1_score": 0.574468085, "support": 50},

    {"class": "joy_1", "precision": 0.576271186, "recall": 0.373626374, "f1_score": 0.453333333, "support": 91},
    {"class": "joy_2", "precision": 0.44, "recall": 0.35483871, "f1_score": 0.392857143, "support": 31},
    {"class": "joy_3", "precision": 0.615384615, "recall": 0.666666667, "f1_score": 0.64, "support": 12},

    {"class": "sadness_1", "precision": 0.505376344, "recall": 0.474747475, "f1_score": 0.489583333, "support": 99},
    {"class": "sadness_2", "precision": 0.631578947, "recall": 0.226415094, "f1_score": 0.333333333, "support": 53},
    {"class": "sadness_3", "precision": 0.416666667, "recall": 0.681818182, "f1_score": 0.517241379, "support": 22},

    {"class": "surprise_1", "precision": 0.472727273, "recall": 0.429752066, "f1_score": 0.45021645, "support": 121},
    {"class": "surprise_2", "precision": 0.56097561, "recall": 0.433962264, "f1_score": 0.489361702, "support": 53},
    {"class": "surprise_3", "precision": 0, "recall": 0, "f1_score": 0, "support": 6}
]


# =========================================================
# 4. MANUALLY ENTER 5-FOLD CLASSWISE TEST RESULTS
# =========================================================
# Replace precision, recall, f1_score, support with each fold's final test classwise results.
# You need 15 rows per fold = 75 rows total.

fold_classwise_results = [

    # =========================
    # Fold 1
    # =========================
   
 

    {"fold": 1, "class": "anger_1", "precision": 0.277777778, "recall": 0.138888889, "f1_score": 0.185185185, "support": 36},
    {"fold": 1, "class": "anger_2", "precision": 0.0000, "recall": 0.0000, "f1_score": 0.0000, "support": 15},
    {"fold": 1, "class": "anger_3", "precision": 0.0000, "recall": 0.0000, "f1_score": 0.0000, "support": 9},

    {"fold": 1, "class": "fear_1", "precision": 0
"support": 121},
    {"fold": 4, "class": "surprise_2", "precision": 0.476190476, "recall": 0.188679245, "f1_score": 0.27027027, "support": 53},
    {"fold": 4, "class": "surprise_3", "precision": 0, "recall": 0, "f1_score": 0, "support": 6},


    # =========================
    # Fold 5
    # =========================


    {"fold": 5, "class": "anger_1", "precision": 0.285714286, "recall": 0.055555556, "f1_score": 0.093023256, "support": 36},
    {"fold": 5, "class": "anger_2", "precision": 0.333333333, "recall": 0.2, "f1_score": 0.25, "support": 15},
    {"fold": 5, "class": "anger_3", "precision": 0, "recall": 0, "f1_score": 0, "support": 9},

    {"fold": 5, "class": "fear_1", "precision": 0.529411765, "recall": 0.396226415, "f1_score": 0.45323741, "support": 159},
    {"fold": 5, "class": "fear_2", "precision": 0.425925926, "recall": 0.464646465, "f1_score": 0.444444444, "support": 99},
    {"fold": 5, "class": "fear_3", "precision": 0.526315789, "recall": 0.6, "f1_score": 0.560747664, "support": 50},

    {"fold": 5, "class": "joy_1", "precision": 0.655172414, "recall": 0.417582418, "f1_score": 0.510067114, "support": 91},
    {"fold": 5, "class": "joy_2", "precision": 0.628571429, "recall": 0.709677419, "f1_score": 0.666666667, "support": 31},
    {"fold": 5, "class": "joy_3", "precision": 0.9, "recall": 0.75, "f1_score": 0.818181818, "support": 12},

    {"fold": 5, "class": "sadness_1", "precision": 0.465517241, "recall": 0.272727273, "f1_score": 0.343949045, "support": 99},
    {"fold": 5, "class": "sadness_2", "precision": 0.166666667, "recall": 0.018867925, "f1_score": 0.033898305, "support": 53},
    {"fold": 5, "class": "sadness_3", "precision": 0.424242424, "recall": 0.636363636, "f1_score": 0.509090909, "support": 22},

    {"fold": 5, "class": "surprise_1", "precision": 0.465346535, "recall": 0.388429752, "f1_score": 0.423423423, "support": 121},
    {"fold": 5, "class": "surprise_2", "precision": 0.522727273, "recall": 0.433962264, "f1_score": 0.474226804, "support": 53},
    {"fold": 5, "class": "surprise_3", "precision": 0, "recall": 0, "f1_score": 0, "support": 6}
]


# =========================================================
# 5. CREATE DATAFRAMES
# =========================================================

original_overall_df = pd.DataFrame([
    {"metric": metric, "original_value": value}
    for metric, value in original_overall.items()
])

fold_overall_df = pd.DataFrame(fold_overall_results)
original_classwise_df = pd.DataFrame(original_classwise_results)
fold_classwise_df = pd.DataFrame(fold_classwise_results)


# =========================================================
# 6. VALIDATION CHECKS
# =========================================================

required_overall_metrics = [
    "test_loss",
    "test_f1_macro",
    "test_f1_micro",
    "test_pearson_mean"
]

required_classes = [
    "anger_1", "anger_2", "anger_3",
    "fear_1", "fear_2", "fear_3",
    "joy_1", "joy_2", "joy_3",
    "sadness_1", "sadness_2", "sadness_3",
    "surprise_1", "surprise_2", "surprise_3"
]

# Check overall columns
for col in ["fold"] + required_overall_metrics:
    if col not in fold_overall_df.columns:
        raise ValueError(f"Missing column in fold_overall_results: {col}")

# Check classwise columns
for col in ["class", "precision", "recall", "f1_score", "support"]:
    if col not in original_classwise_df.columns:
        raise ValueError(f"Missing column in original_classwise_results: {col}")

for col in ["fold", "class", "precision", "recall", "f1_score", "support"]:
    if col not in fold_classwise_df.columns:
        raise ValueError(f"Missing column in fold_classwise_results: {col}")

# Check number of fold overall rows
if len(fold_overall_df) != 5:
    raise ValueError("fold_overall_results must contain exactly 5 rows, one for each fold.")

# Check classes in original
missing_original_classes = set(required_classes) - set(original_classwise_df["class"])
if missing_original_classes:
    raise ValueError(f"Missing classes in original_classwise_results: {missing_original_classes}")

# Check classes in every fold
for fold in [1, 2, 3, 4, 5]:
    fold_classes = set(fold_classwise_df[fold_classwise_df["fold"] == fold]["class"])
    missing_fold_classes = set(required_classes) - fold_classes
    if missing_fold_classes:
        raise ValueError(f"Missing classes in fold {fold}: {missing_fold_classes}")


# =========================================================
# 7. OVERALL MODEL COMPARISON TABLE
# =========================================================

fold_overall_mean = fold_overall_df[required_overall_metrics].mean()
fold_overall_std = fold_overall_df[required_overall_metrics].std()

overall_comparison_table = pd.DataFrame({
    "metric": required_overall_metrics,
    "original_value": [original_overall[m] for m in required_overall_metrics],
    "cv_mean": [fold_overall_mean[m] for m in required_overall_metrics],
    "cv_std": [fold_overall_std[m] for m in required_overall_metrics]
})

overall_comparison_table["cv_mean ± std"] = (
    overall_comparison_table["cv_mean"].round(4).astype(str)
    + " ± "
    + overall_comparison_table["cv_std"].round(4).astype(str)
)


# =========================================================
# 8. CLASSWISE COMPARISON TABLE
# =========================================================

fold_classwise_mean = (
    fold_classwise_df
    .groupby("class")
    .agg(
        precision_cv_mean=("precision", "mean"),
        recall_cv_mean=("recall", "mean"),
        f1_cv_mean=("f1_score", "mean"),
        support_cv_mean=("support", "mean")
    )
    .reset_index()
)

classwise_comparison_table = original_classwise_df.merge(
    fold_classwise_mean,
    on="class",
    how="left"
)

classwise_comparison_table = classwise_comparison_table.rename(columns={
    "precision": "precision_original",
    "recall": "recall_original",
    "f1_score": "f1_original",
    "support": "support_original"
})

classwise_comparison_table = classwise_comparison_table[
    [
        "class",
        "precision_original",
        "precision_cv_mean",
        "recall_original",
        "recall_cv_mean",
        "f1_original",
        "f1_cv_mean",
        "support_original",
        "support_cv_mean"
    ]
]


# =========================================================
# 9. ROUND VALUES FOR DISPLAY
# =========================================================

overall_comparison_table_display = overall_comparison_table.copy()
for col in ["original_value", "cv_mean", "cv_std"]:
    overall_comparison_table_display[col] = overall_comparison_table_display[col].round(4)

classwise_comparison_table_display = classwise_comparison_table.copy()
for col in [
    "precision_original",
    "precision_cv_mean",
    "recall_original",
    "recall_cv_mean",
    "f1_original",
    "f1_cv_mean",
    "support_cv_mean"
]:
    classwise_comparison_table_display[col] = classwise_comparison_table_display[col].round(4)


# =========================================================
# 10. DISPLAY ONLY TWO TABLES
# =========================================================
print("Results for Roberta (8,8) hierarchical model with 5-fold cross validation on the test set.")
print("OVERALL MODEL COMPARISON")
display(overall_comparison_table_display)

print("CLASSWISE COMPARISON")
display(classwise_comparison_table_display)
# Out:
# Results for Roberta (8,8) hierarchical model with 5-fold cross validation on the test set.
# OVERALL MODEL COMPARISON
#               metric  original_value  cv_mean  cv_std    cv_mean ± std
# 0          test_loss          0.5841   0.5612  0.0160   0.5612 ± 0.016
# 1      test_f1_macro          0.3783   0.3407  0.0480   0.3407 ± 0.048
# 2      test_f1_micro          0.4498   0.4219  0.0298  0.4219 ± 0.0298
# 3  test_pearson_mean          0.4515   0.4485  0.0096  0.4485 ± 0.0096
# CLASSWISE COMPARISON
#          class  precision_original  precision_cv_mean  recall_original  \
# 0      anger_1              0.2667             0.3213           0.1111
# 1      anger_2              0.3333             0.3103           0.2000
# 2      anger_3              0.0000             0.1000           0.0000
# 3       fear_1              0.4356             0.4759           0.4465
# 4       fear_2              0.4275             0.4314           0.5657
# ...

# %%
# =========================================================
# FINAL MANUAL ANALYSIS CODE
# Original Model vs 5-Fold Cross Validation
# Outputs ONLY TWO TABLES
# =========================================================

import pandas as pd
import numpy as np

# =========================================================
# ORIGINAL OVERALL RESULTS
# =========================================================

original_overall = {
    "test_loss": 0.601360,
    "test_f1_macro": 0.291135,
    "test_f1_micro": 0.389070,
    "test_pearson_mean": 0.407934
}


# =========================================================
# FIVE-FOLD OVERALL RESULTS
# =========================================================

fold_overall_results = [
    {
        "fold": 1,
        "test_loss": 0.614764214,
        "test_f1_macro": 0.338421111,
        "test_f1_micro": 0.392809587,
        "test_pearson_mean": 0.421677584
    },
    {
        "fold": 2,
        "test_loss": 0.600352466,
        "test_f1_macro": 0.286118204,
        "test_f1_micro": 0.377233620,
        "test_pearson_mean": 0.405259446
    },
    {
        "fold": 3,
        "test_loss": 0.603024840,
        "test_f1_macro": 0.314920020,
        "test_f1_micro": 0.404580153,
        "test_pearson_mean": 0.414518550
    },
    {
        "fold": 4,
        "test_loss": 0.610815108,
        "test_f1_macro": 0.291084752,
        "test_f1_micro": 0.373015873,
        "test_pearson_mean": 0.401073257
    },
    {
        "fold": 5,
        "test_loss": 0.604101360,
        "test_f1_macro": 0.326002494,
        "test_f1_micro": 0.394754098,
        "test_pearson_mean": 0.405956801
    }
]


# =========================================================
# ORIGINAL CLASSWISE RESULTS
# =========================================================

original_classwise_results = [
    {"class": "anger_1", "precision": 0.500000, "recall": 0.138889, "f1_score": 0.217391, "support": 36},
    {"class": "anger_2", "precision": 0.400000, "recall": 0.133333, "f1_score": 0.200000, "support": 15},
    {"class": "anger_3", "precision": 0.000000, "recall": 0.000000, "f1_score": 0.000000, "support":
"support": 99},
    {"fold": 3, "class": "sadness_2", "precision": 0.571428571, "recall": 0.075471698, "f1_score": 0.133333333, "support": 53},
    {"fold": 3, "class": "sadness_3", "precision": 0.560000000, "recall": 0.636363636, "f1_score": 0.595744681, "support": 22},

    {"fold": 3, "class": "surprise_1", "precision": 0.415384615, "recall": 0.446280992, "f1_score": 0.430278884, "support": 121},
    {"fold": 3, "class": "surprise_2", "precision": 0.565217391, "recall": 0.245283019, "f1_score": 0.342105263, "support": 53},
    {"fold": 3, "class": "surprise_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 6},


    # =========================
    # Fold 4
    # =========================
    {"fold": 4, "class": "anger_1", "precision": 0.333333333, "recall": 0.111111111, "f1_score": 0.166666667, "support": 36},
    {"fold": 4, "class": "anger_2", "precision": 1.000000000, "recall": 0.133333333, "f1_score": 0.235294118, "support": 15},
    {"fold": 4, "class": "anger_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 9},

    {"fold": 4, "class": "fear_1", "precision": 0.460317460, "recall": 0.364779874, "f1_score": 0.407017544, "support": 159},
    {"fold": 4, "class": "fear_2", "precision": 0.391304348, "recall": 0.545454545, "f1_score": 0.455696203, "support": 99},
    {"fold": 4, "class": "fear_3", "precision": 0.648648649, "recall": 0.480000000, "f1_score": 0.551724138, "support": 50},

    {"fold": 4, "class": "joy_1", "precision": 0.461538462, "recall": 0.329670330, "f1_score": 0.384615385, "support": 91},
    {"fold": 4, "class": "joy_2", "precision": 0.312500000, "recall": 0.161290323, "f1_score": 0.212765957, "support": 31},
    {"fold": 4, "class": "joy_3", "precision": 0.750000000, "recall": 0.250000000, "f1_score": 0.375000000, "support": 12},

    {"fold": 4, "class": "sadness_1", "precision": 0.355371901, "recall": 0.434343434, "f1_score": 0.390909091, "support": 99},
    {"fold": 4, "class": "sadness_2", "precision": 0.250000000, "recall": 0.037735849, "f1_score": 0.065573770, "support": 53},
    {"fold": 4, "class": "sadness_3", "precision": 0.521739130, "recall": 0.545454545, "f1_score": 0.533333333, "support": 22},

    {"fold": 4, "class": "surprise_1", "precision": 0.415730337, "recall": 0.305785124, "f1_score": 0.352380952, "support": 121},
    {"fold": 4, "class": "surprise_2", "precision": 0.533333333, "recall": 0.150943396, "f1_score": 0.235294118, "support": 53},
    {"fold": 4, "class": "surprise_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 6},


    # =========================
    # Fold 5
    # =========================
    {"fold": 5, "class": "anger_1", "precision": 0.666666667, "recall": 0.111111111, "f1_score": 0.190476190, "support": 36},
    {"fold": 5, "class": "anger_2", "precision": 0.500000000, "recall": 0.200000000, "f1_score": 0.285714286, "support": 15},
    {"fold": 5, "class": "anger_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 9},

    {"fold": 5, "class": "fear_1", "precision": 0.464912281, "recall": 0.333333333, "f1_score": 0.388278388, "support": 159},
    {"fold": 5, "class": "fear_2", "precision": 0.379032258, "recall": 0.474747475, "f1_score": 0.421524664, "support": 99},
    {"fold": 5, "class": "fear_3", "precision": 0.595238095, "recall": 0.500000000, "f1_score": 0.543478261, "support": 50},

    {"fold": 5, "class": "joy_1", "precision": 0.491803279, "recall": 0.329670330, "f1_score": 0.394736842, "support": 91},
    {"fold": 5, "class": "joy_2", "precision": 0.428571429, "recall": 0.387096774, "f1_score": 0.406779661, "support": 31},
    {"fold": 5, "class": "joy_3", "precision": 0.666666667, "recall": 0.333333333, "f1_score": 0.444444444, "support": 12},

    {"fold": 5, "class": "sadness_1", "precision": 0.444444444, "recall": 0.363636364, "f1_score": 0.400000000, "support": 99},
    {"fold": 5, "class": "sadness_2", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 53},
    {"fold": 5, "class": "sadness_3", "precision": 0.517241379, "recall": 0.681818182, "f1_score": 0.588235294, "support": 22},

    {"fold": 5, "class": "surprise_1", "precision": 0.400000000, "recall": 0.446280992, "f1_score": 0.421875000, "support": 121},
    {"fold": 5, "class": "surprise_2", "precision": 0.500000000, "recall": 0.339622642, "f1_score": 0.404494382, "support": 53},
    {"fold": 5, "class": "surprise_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 6}
]


	



# =========================================================
# 5. CREATE DATAFRAMES
# =========================================================

original_overall_df = pd.DataFrame([
    {"metric": metric, "original_value": value}
    for metric, value in original_overall.items()
])

fold_overall_df = pd.DataFrame(fold_overall_results)
original_classwise_df = pd.DataFrame(original_classwise_results)
fold_classwise_df = pd.DataFrame(fold_classwise_results)


# =========================================================
# 6. VALIDATION CHECKS
# =========================================================

required_overall_metrics = [
    "test_loss",
    "test_f1_macro",
    "test_f1_micro",
    "test_pearson_mean"
]

required_classes = [
    "anger_1", "anger_2", "anger_3",
    "fear_1", "fear_2", "fear_3",
    "joy_1", "joy_2", "joy_3",
    "sadness_1", "sadness_2", "sadness_3",
    "surprise_1", "surprise_2", "surprise_3"
]

# Check overall columns
for col in ["fold"] + required_overall_metrics:
    if col not in fold_overall_df.columns:
        raise ValueError(f"Missing column in fold_overall_results: {col}")

# Check classwise columns
for col in ["class", "precision", "recall", "f1_score", "support"]:
    if col not in original_classwise_df.columns:
        raise ValueError(f"Missing column in original_classwise_results: {col}")

for col in ["fold", "class", "precision", "recall", "f1_score", "support"]:
    if col not in fold_classwise_df.columns:
        raise ValueError(f"Missing column in fold_classwise_results: {col}")

# Check number of fold overall rows
if len(fold_overall_df) != 5:
    raise ValueError("fold_overall_results must contain exactly 5 rows, one for each fold.")

# Check classes in original
missing_original_classes = set(required_classes) - set(original_classwise_df["class"])
if missing_original_classes:
    raise ValueError(f"Missing classes in original_classwise_results: {missing_original_classes}")

# Check classes in every fold
for fold in [1, 2, 3, 4, 5]:
    fold_classes = set(fold_classwise_df[fold_classwise_df["fold"] == fold]["class"])
    missing_fold_classes = set(required_classes) - fold_classes
    if missing_fold_classes:
        raise ValueError(f"Missing classes in fold {fold}: {missing_fold_classes}")


# =========================================================
# 7. OVERALL MODEL COMPARISON TABLE
# =========================================================

fold_overall_mean = fold_overall_df[required_overall_metrics].mean()
fold_overall_std = fold_overall_df[required_overall_metrics].std()

overall_comparison_table = pd.DataFrame({
    "metric": required_overall_metrics,
    "original_value": [original_overall[m] for m in required_overall_metrics],
    "cv_mean": [fold_overall_mean[m] for m in required_overall_metrics],
    "cv_std": [fold_overall_std[m] for m in required_overall_metrics]
})

overall_comparison_table["cv_mean ± std"] = (
    overall_comparison_table["cv_mean"].round(4).astype(str)
    + " ± "
    + overall_comparison_table["cv_std"].round(4).astype(str)
)


# =========================================================
# 8. CLASSWISE COMPARISON TABLE
# =========================================================

fold_classwise_mean = (
    fold_classwise_df
    .groupby("class")
    .agg(
        precision_cv_mean=("precision", "mean"),
        recall_cv_mean=("recall", "mean"),
        f1_cv_mean=("f1_score", "mean"),
        support_cv_mean=("support", "mean")
    )
    .reset_index()
)

classwise_comparison_table = original_classwise_df.merge(
    fold_classwise_mean,
    on="class",
    how="left"
)

classwise_comparison_table = classwise_comparison_table.rename(columns={
    "precision": "precision_original",
    "recall": "recall_original",
    "f1_score": "f1_original",
    "support": "support_original"
})

classwise_comparison_table = classwise_comparison_table[
    [
        "class",
        "precision_original",
        "precision_cv_mean",
        "recall_original",
        "recall_cv_mean",
        "f1_original",
        "f1_cv_mean",
        "support_original",
        "support_cv_mean"
    ]
]


# =========================================================
# 9. ROUND VALUES FOR DISPLAY
# =========================================================

overall_comparison_table_display = overall_comparison_table.copy()
for col in ["original_value", "cv_mean", "cv_std"]:
    overall_comparison_table_display[col] = overall_comparison_table_display[col].round(4)

classwise_comparison_table_display = classwise_comparison_table.copy()
for col in [
    "precision_original",
    "precision_cv_mean",
    "recall_original",
    "recall_cv_mean",
    "f1_original",
    "f1_cv_mean",
    "support_cv_mean"
]:
    classwise_comparison_table_display[col] = classwise_comparison_table_display[col].round(4)


# =========================================================
# 10. DISPLAY ONLY TWO TABLES
# =========================================================
print("Results for DistillBERT (8,8) hierarchical model with 5-fold cross validation on the test set.")
print("OVERALL MODEL COMPARISON")
display(overall_comparison_table_display)

print("CLASSWISE COMPARISON")
display(classwise_comparison_table_display)
# Out:
# Results for DistillBERT (8,8) hierarchical model with 5-fold cross validation on the test set.
# OVERALL MODEL COMPARISON
#               metric  original_value  cv_mean  cv_std    cv_mean ± std
# 0          test_loss          0.6014   0.6066  0.0060   0.6066 ± 0.006
# 1      test_f1_macro          0.2911   0.3113  0.0224  0.3113 ± 0.0224
# 2      test_f1_micro          0.3891   0.3885  0.0131  0.3885 ± 0.0131
# 3  test_pearson_mean          0.4079   0.4097  0.0083  0.4097 ± 0.0083
# CLASSWISE COMPARISON
#          class  precision_original  precision_cv_mean  recall_original  \
# 0      anger_1              0.5000             0.4980           0.1389
# 1      anger_2              0.4000             0.5317           0.1333
# 2      anger_3              0.0000             0.0000           0.0000
# 3       fear_1              0.3980             0.4355           0.5031
# 4       fear_2              0.3977             0.3778           0.3535
# ...

# %%
# =========================================================
# FINAL MANUAL ANALYSIS CODE
# Original Model vs 5-Fold Cross Validation
# Outputs ONLY TWO TABLES
# =========================================================

import pandas as pd
import numpy as np

# =========================================================
# 1. MANUALLY ENTER ORIGINAL MODEL OVERALL TEST RESULTS
# =========================================================
# Replace the 0.0000 values with your original model test results


	

original_overall = {

    "test_loss": 0.609104633,
    "test_f1_macro": 0.269349623,
    "test_f1_micro": 0.380519481,
    "test_pearson_mean": 0.406383605
}


# =========================================================
# 2. MANUALLY ENTER 5-FOLD OVERALL TEST RESULTS
# =========================================================
# Replace all 0.0000 values with the final test results from each fold

fold_overall_results = [
    {
       

        "fold": 1,
        "test_loss": 0.614764214,
        "test_f1_macro": 0.338421111,
        "test_f1_micro": 0.392809587,
        "test_pearson_mean": 0.421677584
    },
    {
        

        "fold": 2,
        "test_loss": 0.60302484,
        "test_f1_macro": 0.286118204,
        "test_f1_micro": 0.37723362,
        "test_pearson_mean": 0.405259446
    },
    {


        "fold": 3,
        "test_loss": 0.60302484,
        "test_f1_macro": 0.31492002,
        "test_f1_micro": 0.404580153,
        "test_pearson_mean": 0.41451855
    },
    {
        "fold": 4,
        "test_loss": 0.610815108,
        "test_f1_macro": 0.291084752,
        "test_f1_micro": 0.373015873,
        "test_pearson_mean": 0.401073257
    } ,
    {

        "fold": 5,
        "test_loss": 0.60410136,
        "test_f1_macro": 0.326002494,
        "test_f1_micro": 0.394754098,
        "test_pearson_mean": 0.405956801
    }
    
]


# =========================================================
# 3. MANUALLY ENTER ORIGINAL MODEL CLASSWISE TEST RESULTS
# =========================================================
# Replace precision, recall, f1_score, support with original model values


original_classwise_results = [


    {"class": "anger_1", "precision": 0.25, "recall": 0.111111111, "f1_score": 0.156862745, "support": 36},
    {"class": "anger_2", "precision": 0, "recall": 0, "f1_score": 0, "support": 15},
    {"class": "anger_3", "precision": 0, "recall": 0, "f1_score": 0, "support": 9},

    {"class": "fear_1", "precision": 0.398843931, "recall": 0.433962264, "f1_score": 0.415662651, "support": 159},
    {"class": "fear_2", "precision": 0.359649123, "recall": 0.414141414, "f1_score": 0.384976526, "support": 99},
    {"class": "fear_3", "precision": 0.666666667, "recall": 0.32, "f1_score": 0.432432432, "support": 50},

    {"class": "joy_1", "precision": 0.479452055, "recall": 0.384615385, "f1_score": 0.426829268, "support": 91},
    {"class": "joy_2", "precision": 0.347826087, "recall": 0.258064516, "f1_score": 0.296296296, "support": 31},
    {"class": "joy_3", "precision": 0.0, "recall": 0.0, "f1_score": 0.0, "support": 12},

    {"class": "sadness_1", "precision": 0.402298851, "recall": 0.353535354, "f1_score": 0.376344086, "support": 99},
    {"class": "sadness_2", "precision": 0.470588235, "recall": 0.150943396, "f1_score": 0.228571429, "support": 53},
    {"class": "sadness_3", "precision": 0.545454545, "recall": 0.545454545, "f1_score": 0.545454545, "support": 22},

    {"class": "surprise_1", "precision": 0.464912281, "recall": 0.438016529, "f1_score": 0.45106383, "support": 121},
    {"class": "surprise_2", "precision": 0.6, "recall": 0.226415094, "f1_score": 0.328767123, "support": 53},
    {"class": "surprise_3", "precision": 0, "recall": 0, "f1_score": 0, "support": 6}
]


# =========================================================
# 4. MANUALLY ENTER 5-FOLD CLASSWISE TEST RESULTS
# =========================================================
# Replace precision, recall, f1_score, support with each fold's final test classwise results.
# You need 15 rows per fold = 75 rows total.

fold_classwise_results = [

    # =========================
    # Fold 1
    # =========================
  
 

    {"fold": 1, "class": "anger_1", "precision": 0.444444444, "recall": 0.111111111, "f1_score": 0.177777778, "support": 36},
    {"fold": 1, "class": "anger_2", "precision": 0.444444444, "recall": 0.266666667, "f1_score": 0.333333333, "support": 15},
    {"fold": 1, "class": "anger_3", "precision": 0.0000, "recall": 0.0000, "f1_score": 0.0000, "support": 9},

    {"fold": 1, "class": "fear_1", "precision": 0.41025641, "recall": 0.402515723, "f1_score": 0.406349206, "support": 159},
    {"fold": 1, "class": "fear_2", "precision": 0.337078652, "recall": 0.303030303, "f1_score": 0.319148936, "support": 99},
    {"fold": 1, "class": "fear_3", "precision": 0.675675676, "recall": 0.5, "f1_score": 0.574712644, "support": 50},

    {"fold": 1, "class": "joy_1", "precision": 0.436619718, "recall": 0.340659341, "f1_score": 0.382716049, "support": 91},
    {"fold": 1, "class": "joy_2", "precision": 0.333333333, "recall": 0.096774194, "f1_score": 0.15, "support": 31},
    {"fold": 1, "class": "joy_3", "precision": 0.666666667, "recall": 0.5, "f1_score": 0.571428571, "support": 12},

    {"fold": 1, "class": "sadness_1", "precision": 0.428571429, "recall": 0.333333333, "f1_score": 0.375, "support": 99},
    {"fold": 1, "class": "sadness_2", "precision": 0.652173913, "recall": 0.283018868, "f1_score": 0.394736842, "support": 53},
    {"fold": 1, "class": "sadness_3", "precision": 0.631578947, "recall": 0.545454545, "f1_score": 0.585365854, "support": 22},

    {"fold": 1, "class": "surprise_1", "precision": 0
"support": 31},
    {"fold": 5, "class": "joy_3", "precision": 0.666666667, "recall": 0.333333333, "f1_score": 0.444444444, "support": 12},

    {"fold": 5, "class": "sadness_1", "precision": 0.444444444, "recall": 0.363636364, "f1_score": 0.4, "support": 99},
    {"fold": 5, "class": "sadness_2", "precision": 0.0, "recall": 0.0, "f1_score": 0.0, "support": 53},
    {"fold": 5, "class": "sadness_3", "precision": 0.424242424, "recall": 0.636363636, "f1_score": 0.509090909, "support": 22},

    {"fold": 5, "class": "surprise_1", "precision": 0.4, "recall": 0.446280992, "f1_score": 0.421875, "support": 121},
    {"fold": 5, "class": "surprise_2", "precision": 0.5, "recall": 0.339622642, "f1_score": 0.404494382, "support": 53},
    {"fold": 5, "class": "surprise_3", "precision": 0, "recall": 0, "f1_score": 0, "support": 6}
]


# =========================================================
# 5. CREATE DATAFRAMES
# =========================================================

original_overall_df = pd.DataFrame([
    {"metric": metric, "original_value": value}
    for metric, value in original_overall.items()
])

fold_overall_df = pd.DataFrame(fold_overall_results)
original_classwise_df = pd.DataFrame(original_classwise_results)
fold_classwise_df = pd.DataFrame(fold_classwise_results)


# =========================================================
# 6. VALIDATION CHECKS
# =========================================================

required_overall_metrics = [
    "test_loss",
    "test_f1_macro",
    "test_f1_micro",
    "test_pearson_mean"
]

required_classes = [
    "anger_1", "anger_2", "anger_3",
    "fear_1", "fear_2", "fear_3",
    "joy_1", "joy_2", "joy_3",
    "sadness_1", "sadness_2", "sadness_3",
    "surprise_1", "surprise_2", "surprise_3"
]

# Check overall columns
for col in ["fold"] + required_overall_metrics:
    if col not in fold_overall_df.columns:
        raise ValueError(f"Missing column in fold_overall_results: {col}")

# Check classwise columns
for col in ["class", "precision", "recall", "f1_score", "support"]:
    if col not in original_classwise_df.columns:
        raise ValueError(f"Missing column in original_classwise_results: {col}")

for col in ["fold", "class", "precision", "recall", "f1_score", "support"]:
    if col not in fold_classwise_df.columns:
        raise ValueError(f"Missing column in fold_classwise_results: {col}")

# Check number of fold overall rows
if len(fold_overall_df) != 5:
    raise ValueError("fold_overall_results must contain exactly 5 rows, one for each fold.")

# Check classes in original
missing_original_classes = set(required_classes) - set(original_classwise_df["class"])
if missing_original_classes:
    raise ValueError(f"Missing classes in original_classwise_results: {missing_original_classes}")

# Check classes in every fold
for fold in [1, 2, 3, 4, 5]:
    fold_classes = set(fold_classwise_df[fold_classwise_df["fold"] == fold]["class"])
    missing_fold_classes = set(required_classes) - fold_classes
    if missing_fold_classes:
        raise ValueError(f"Missing classes in fold {fold}: {missing_fold_classes}")


# =========================================================
# 7. OVERALL MODEL COMPARISON TABLE
# =========================================================

fold_overall_mean = fold_overall_df[required_overall_metrics].mean()
fold_overall_std = fold_overall_df[required_overall_metrics].std()

overall_comparison_table = pd.DataFrame({
    "metric": required_overall_metrics,
    "original_value": [original_overall[m] for m in required_overall_metrics],
    "cv_mean": [fold_overall_mean[m] for m in required_overall_metrics],
    "cv_std": [fold_overall_std[m] for m in required_overall_metrics]
})

overall_comparison_table["cv_mean ± std"] = (
    overall_comparison_table["cv_mean"].round(4).astype(str)
    + " ± "
    + overall_comparison_table["cv_std"].round(4).astype(str)
)


# =========================================================
# 8. CLASSWISE COMPARISON TABLE
# =========================================================

fold_classwise_mean = (
    fold_classwise_df
    .groupby("class")
    .agg(
        precision_cv_mean=("precision", "mean"),
        recall_cv_mean=("recall", "mean"),
        f1_cv_mean=("f1_score", "mean"),
        support_cv_mean=("support", "mean")
    )
    .reset_index()
)

classwise_comparison_table = original_classwise_df.merge(
    fold_classwise_mean,
    on="class",
    how="left"
)

classwise_comparison_table = classwise_comparison_table.rename(columns={
    "precision": "precision_original",
    "recall": "recall_original",
    "f1_score": "f1_original",
    "support": "support_original"
})

classwise_comparison_table = classwise_comparison_table[
    [
        "class",
        "precision_original",
        "precision_cv_mean",
        "recall_original",
        "recall_cv_mean",
        "f1_original",
        "f1_cv_mean",
        "support_original",
        "support_cv_mean"
    ]
]


# =========================================================
# 9. ROUND VALUES FOR DISPLAY
# =========================================================

overall_comparison_table_display = overall_comparison_table.copy()
for col in ["original_value", "cv_mean", "cv_std"]:
    overall_comparison_table_display[col] = overall_comparison_table_display[col].round(4)

classwise_comparison_table_display = classwise_comparison_table.copy()
for col in [
    "precision_original",
    "precision_cv_mean",
    "recall_original",
    "recall_cv_mean",
    "f1_original",
    "f1_cv_mean",
    "support_cv_mean"
]:
    classwise_comparison_table_display[col] = classwise_comparison_table_display[col].round(4)


# =========================================================
# 10. DISPLAY ONLY TWO TABLES
# =========================================================
print("Results for DistilBERT (16,16) hierarchical model with 5-fold cross validation on the test set.")
print("OVERALL MODEL COMPARISON")
display(overall_comparison_table_display)

print("CLASSWISE COMPARISON")
display(classwise_comparison_table_display)
# Out:
# Results for DistilBERT (16,16) hierarchical model with 5-fold cross validation on the test set.
# OVERALL MODEL COMPARISON
#               metric  original_value  cv_mean  cv_std    cv_mean ± std
# 0          test_loss          0.6091   0.6071  0.0054  0.6071 ± 0.0054
# 1      test_f1_macro          0.2693   0.3113  0.0224  0.3113 ± 0.0224
# 2      test_f1_micro          0.3805   0.3885  0.0131  0.3885 ± 0.0131
# 3  test_pearson_mean          0.4064   0.4097  0.0083  0.4097 ± 0.0083
# CLASSWISE COMPARISON
#          class  precision_original  precision_cv_mean  recall_original  \
# 0      anger_1              0.2500             0.4980           0.1111
# 1      anger_2              0.0000             0.5317           0.0000
# 2      anger_3              0.0000             0.0000           0.0000
# 3       fear_1              0.3988             0.4355           0.4340
# 4       fear_2              0.3596             0.3792           0.4141
# ...

# %%
# =========================================================
# FINAL MANUAL ANALYSIS CODE
# Original Model vs 5-Fold Cross Validation
# Outputs ONLY TWO TABLES
# =========================================================

import pandas as pd
import numpy as np

# =========================================================
# ORIGINAL OVERALL RESULTS
# =========================================================

original_overall = {
    "test_loss": 0.237975910,
    "test_f1_macro": 0.148924920,
    "test_f1_micro": 0.192523364,
    "test_pearson_mean": 0.400601138
}


# =========================================================
# FIVE-FOLD OVERALL RESULTS
# =========================================================

fold_overall_results = [
    {
        "fold": 1,
        "test_loss": 0.234565586,
        "test_f1_macro": 0.180563428,
        "test_f1_micro": 0.283347142,
        "test_pearson_mean": 0.404017810
    },
    {
        "fold": 2,
        "test_loss": 0.238581911,
        "test_f1_macro": 0.271043189,
        "test_f1_micro": 0.342774147,
        "test_pearson_mean": 0.408025018
    },
    {
        "fold": 3,
        "test_loss": 0.236316189,
        "test_f1_macro": 0.214651662,
        "test_f1_micro": 0.307573416,
        "test_pearson_mean": 0.407691737
    },
    {
        "fold": 4,
        "test_loss": 0.238122508,
        "test_f1_macro": 0.277525234,
        "test_f1_micro": 0.332570557,
        "test_pearson_mean": 0.393839214
    },
    {
        "fold": 5,
        "test_loss": 0.239448667,
        "test_f1_macro": 0.201578067,
        "test_f1_micro": 0.295774648,
        "test_pearson_mean": 0.392565390
    }
]


# =========================================================
# ORIGINAL CLASSWISE RESULTS
# =========================================================

original_classwise_results = [
    {"class": "anger_1", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 36},
    {"class": "anger_2", "precision": 1.000000000, "recall": 0.066666667, "f1_score": 0.125000000, "support": 15},
    {"class": "anger_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 9},

    {"class": "fear_1", "precision": 0.350000000, "recall": 0.088050314, "f1_score": 0.140703518, "support": 159},
    {"class": "fear_2", "precision": 0.368421053, "recall": 0.141414141, "f1_score": 0.204379562, "support": 99},
    {"class": "fear_3", "precision": 0.789473684, "recall": 0.300000000, "f1_score": 0.434782609, "support": 50},

    {"class": "joy_1", "precision": 0.641025641, "recall": 0.274725275, "f1_score": 0.384615385, "support": 91},
    {"class": "joy_2", "precision": 0.428571429, "recall": 0.096774194, "f1_score": 0.157894737, "support": 31},
    {"class": "joy_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 12},

    {"class": "sadness_1", "precision": 0.300000000, "recall": 0.030303030, "f1_score": 0.055045872, "support": 99},
    {"class": "sadness_2", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 53},
    {"class": "sadness_3", "precision": 0.600000000, "recall": 0.272727273, "f1_score": 0.375000000, "support": 22},

    {"class": "surprise_1", "precision": 0.428571429, "recall": 0.148760331, "f1_score": 0.220858896, "support": 121},
    {"class": "surprise_2", "precision": 0.666666667, "recall": 0.075471698, "f1_score": 0.135593220, "support": 53},
    {"class": "surprise_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 6}
"support": 159},
    {"fold": 5, "class": "fear_2", "precision": 0.326530612, "recall": 0.161616162, "f1_score": 0.216216216, "support": 99},
    {"fold": 5, "class": "fear_3", "precision": 0.633333333, "recall": 0.380000000, "f1_score": 0.475000000, "support": 50},

    {"fold": 5, "class": "joy_1", "precision": 0.490566038, "recall": 0.285714286, "f1_score": 0.361111111, "support": 91},
    {"fold": 5, "class": "joy_2", "precision": 0.500000000, "recall": 0.096774194, "f1_score": 0.162162162, "support": 31},
    {"fold": 5, "class": "joy_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 12},

    {"fold": 5, "class": "sadness_1", "precision": 0.434782609, "recall": 0.202020202, "f1_score": 0.275862069, "support": 99},
    {"fold": 5, "class": "sadness_2", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 53},
    {"fold": 5, "class": "sadness_3", "precision": 0.526315789, "recall": 0.454545455, "f1_score": 0.487804878, "support": 22},

    {"fold": 5, "class": "surprise_1", "precision": 0.404255319, "recall": 0.314049587, "f1_score": 0.353488372, "support": 121},
    {"fold": 5, "class": "surprise_2", "precision": 1.000000000, "recall": 0.113207547, "f1_score": 0.203389831, "support": 53},
    {"fold": 5, "class": "surprise_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 6}
]

# =========================================================
# 5. CREATE DATAFRAMES
# =========================================================

original_overall_df = pd.DataFrame([
    {"metric": metric, "original_value": value}
    for metric, value in original_overall.items()
])

fold_overall_df = pd.DataFrame(fold_overall_results)
original_classwise_df = pd.DataFrame(original_classwise_results)
fold_classwise_df = pd.DataFrame(fold_classwise_results)


# =========================================================
# 6. VALIDATION CHECKS
# =========================================================

required_overall_metrics = [
    "test_loss",
    "test_f1_macro",
    "test_f1_micro",
    "test_pearson_mean"
]

required_classes = [
    "anger_1", "anger_2", "anger_3",
    "fear_1", "fear_2", "fear_3",
    "joy_1", "joy_2", "joy_3",
    "sadness_1", "sadness_2", "sadness_3",
    "surprise_1", "surprise_2", "surprise_3"
]

# Check overall columns
for col in ["fold"] + required_overall_metrics:
    if col not in fold_overall_df.columns:
        raise ValueError(f"Missing column in fold_overall_results: {col}")

# Check classwise columns
for col in ["class", "precision", "recall", "f1_score", "support"]:
    if col not in original_classwise_df.columns:
        raise ValueError(f"Missing column in original_classwise_results: {col}")

for col in ["fold", "class", "precision", "recall", "f1_score", "support"]:
    if col not in fold_classwise_df.columns:
        raise ValueError(f"Missing column in fold_classwise_results: {col}")

# Check number of fold overall rows
if len(fold_overall_df) != 5:
    raise ValueError("fold_overall_results must contain exactly 5 rows, one for each fold.")

# Check classes in original
missing_original_classes = set(required_classes) - set(original_classwise_df["class"])
if missing_original_classes:
    raise ValueError(f"Missing classes in original_classwise_results: {missing_original_classes}")

# Check classes in every fold
for fold in [1, 2, 3, 4, 5]:
    fold_classes = set(fold_classwise_df[fold_classwise_df["fold"] == fold]["class"])
    missing_fold_classes = set(required_classes) - fold_classes
    if missing_fold_classes:
        raise ValueError(f"Missing classes in fold {fold}: {missing_fold_classes}")


# =========================================================
# 7. OVERALL MODEL COMPARISON TABLE
# =========================================================

fold_overall_mean = fold_overall_df[required_overall_metrics].mean()
fold_overall_std = fold_overall_df[required_overall_metrics].std()

overall_comparison_table = pd.DataFrame({
    "metric": required_overall_metrics,
    "original_value": [original_overall[m] for m in required_overall_metrics],
    "cv_mean": [fold_overall_mean[m] for m in required_overall_metrics],
    "cv_std": [fold_overall_std[m] for m in required_overall_metrics]
})

overall_comparison_table["cv_mean ± std"] = (
    overall_comparison_table["cv_mean"].round(4).astype(str)
    + " ± "
    + overall_comparison_table["cv_std"].round(4).astype(str)
)


# =========================================================
# 8. CLASSWISE COMPARISON TABLE
# =========================================================

fold_classwise_mean = (
    fold_classwise_df
    .groupby("class")
    .agg(
        precision_cv_mean=("precision", "mean"),
        recall_cv_mean=("recall", "mean"),
        f1_cv_mean=("f1_score", "mean"),
        support_cv_mean=("support", "mean")
    )
    .reset_index()
)

classwise_comparison_table = original_classwise_df.merge(
    fold_classwise_mean,
    on="class",
    how="left"
)

classwise_comparison_table = classwise_comparison_table.rename(columns={
    "precision": "precision_original",
    "recall": "recall_original",
    "f1_score": "f1_original",
    "support": "support_original"
})

classwise_comparison_table = classwise_comparison_table[
    [
        "class",
        "precision_original",
        "precision_cv_mean",
        "recall_original",
        "recall_cv_mean",
        "f1_original",
        "f1_cv_mean",
        "support_original",
        "support_cv_mean"
    ]
]


# =========================================================
# 9. ROUND VALUES FOR DISPLAY
# =========================================================

overall_comparison_table_display = overall_comparison_table.copy()
for col in ["original_value", "cv_mean", "cv_std"]:
    overall_comparison_table_display[col] = overall_comparison_table_display[col].round(4)

classwise_comparison_table_display = classwise_comparison_table.copy()
for col in [
    "precision_original",
    "precision_cv_mean",
    "recall_original",
    "recall_cv_mean",
    "f1_original",
    "f1_cv_mean",
    "support_cv_mean"
]:
    classwise_comparison_table_display[col] = classwise_comparison_table_display[col].round(4)


# =========================================================
# 10. DISPLAY ONLY TWO TABLES
# =========================================================
print("Results for DistilBERT (8,8) single step approach with 5-fold cross validation on the test set.")
print("OVERALL MODEL COMPARISON")
display(overall_comparison_table_display)

print("CLASSWISE COMPARISON")
display(classwise_comparison_table_display)
# Out:
# Results for DistilBERT (8,8) single step approach with 5-fold cross validation on the test set.
# OVERALL MODEL COMPARISON
#               metric  original_value  cv_mean  cv_std    cv_mean ± std
# 0          test_loss          0.2380   0.2374  0.0020   0.2374 ± 0.002
# 1      test_f1_macro          0.1489   0.2291  0.0431  0.2291 ± 0.0431
# 2      test_f1_micro          0.1925   0.3124  0.0249  0.3124 ± 0.0249
# 3  test_pearson_mean          0.4006   0.4012  0.0075  0.4012 ± 0.0075
# CLASSWISE COMPARISON
#          class  precision_original  precision_cv_mean  recall_original  \
# 0      anger_1              0.0000             0.2952           0.0000
# 1      anger_2              1.0000             0.7333           0.0667
# 2      anger_3              0.0000             0.0000           0.0000
# 3       fear_1              0.3500             0.4291           0.0881
# 4       fear_2              0.3684             0.3669           0.1414
# ...

# %%
# =========================================================
# FINAL MANUAL ANALYSIS CODE
# Original Model vs 5-Fold Cross Validation
# Outputs ONLY TWO TABLES
# =========================================================

import pandas as pd
import numpy as np

# =========================================================
# ORIGINAL OVERALL RESULTS
# =========================================================

original_overall = {
    "test_loss": 0.239240691,
    "test_f1_macro": 0.243293801,
    "test_f1_micro": 0.341781318,
    "test_pearson_mean": 0.401271871
}


# =========================================================
# FIVE-FOLD OVERALL RESULTS
# =========================================================

fold_overall_results = [
    {
        "fold": 1,
        "test_loss": 0.235035092,
        "test_f1_macro": 0.147104450,
        "test_f1_micro": 0.234556849,
        "test_pearson_mean": 0.398724576
    },
    {
        "fold": 2,
        "test_loss": 0.238324463,
        "test_f1_macro": 0.156875094,
        "test_f1_micro": 0.259915612,
        "test_pearson_mean": 0.384764531
    },
    {
        "fold": 3,
        "test_loss": 0.239798054,
        "test_f1_macro": 0.142069199,
        "test_f1_micro": 0.254208754,
        "test_pearson_mean": 0.382662825
    },
    {
        "fold": 4,
        "test_loss": 0.239631429,
        "test_f1_macro": 0.167383766,
        "test_f1_micro": 0.243103448,
        "test_pearson_mean": 0.379747215
    },
    {
        "fold": 5,
        "test_loss": 0.240974471,
        "test_f1_macro": 0.109181726,
        "test_f1_micro": 0.208144796,
        "test_pearson_mean": 0.376477204
    }
]


# =========================================================
# ORIGINAL CLASSWISE RESULTS
# =========================================================

original_classwise_results = [
    {"class": "anger_1", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 36},
    {"class": "anger_2", "precision": 1.000000000, "recall": 0.066666667, "f1_score": 0.125000000, "support": 15},
    {"class": "anger_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 9},

    {"class": "fear_1", "precision": 0.426229508, "recall": 0.327044025, "f1_score": 0.370106762, "support": 159},
    {"class": "fear_2", "precision": 0.364406780, "recall": 0.434343434, "f1_score": 0.396313364, "support": 99},
    {"class": "fear_3", "precision": 0.760000000, "recall": 0.380000000, "f1_score": 0.506666667, "support": 50},

    {"class": "joy_1", "precision": 0.523809524, "recall": 0.241758242, "f1_score": 0.330827068, "support": 91},
    {"class": "joy_2", "precision": 0.538461538, "recall": 0.225806452, "f1_score": 0.318181818, "support": 31},
    {"class": "joy_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 12},

    {"class": "sadness_1", "precision": 0.327868852, "recall": 0.202020202, "f1_score": 0.250000000, "support": 99},
    {"class": "sadness_2", "precision": 1.000000000, "recall": 0.075471698, "f1_score": 0.140350877, "support": 53},
    {"class": "sadness_3", "precision": 0.615384615, "recall": 0.363636364, "f1_score": 0.457142857, "support": 22},

    {"class": "surprise_1", "precision": 0.470588235, "recall": 0.396694215, "f1_score": 0.430493274, "support": 121},
    {"class": "surprise_2", "precision": 0.571428571, "recall": 0.226415094, "f1_score": 0.324324324, "support": 53},
    {"class": "surprise_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 6}
 5-fold cross validation on the test set.
# OVERALL MODEL COMPARISON
#               metric  original_value  cv_mean  cv_std    cv_mean ± std
# 0          test_loss          0.2392   0.2388  0.0023  0.2388 ± 0.0023
# 1      test_f1_macro          0.2433   0.1445  0.0220   0.1445 ± 0.022
# 2      test_f1_micro          0.3418   0.2400  0.0203    0.24 ± 0.0203
# 3  test_pearson_mean          0.4013   0.3845  0.0086  0.3845 ± 0.0086
# CLASSWISE COMPARISON
#          class  precision_original  precision_cv_mean  recall_original  \
# 0      anger_1              0.0000             0.0000           0.0000
# 1      anger_2              1.0000             0.4000           0.0667
# 2      anger_3              0.0000             0.0000           0.0000
# 3       fear_1              0.4262             0.4212           0.3270
# 4       fear_2              0.3644             0.3361           0.4343
# ...

# %%
# =========================================================
# FINAL MANUAL ANALYSIS CODE
# Original Model vs 5-Fold Cross Validation
# Outputs ONLY TWO TABLES
# =========================================================

import pandas as pd
import numpy as np

# =========================================================
# ORIGINAL OVERALL RESULTS
# =========================================================

original_overall = {
    "test_loss": 0.228704,
    "test_f1_macro": 0.278140,
    "test_f1_micro": 0.397820,
    "test_pearson_mean": 0.437495
}


# =========================================================
# FIVE-FOLD OVERALL RESULTS
# =========================================================

fold_overall_results = [
    {
        "fold": 1,
        "test_loss": 0.224047959,
        "test_f1_macro": 0.235860071,
        "test_f1_micro": 0.362395754,
        "test_pearson_mean": 0.429761981
    },
    {
        "fold": 2,
        "test_loss": 0.227893978,
        "test_f1_macro": 0.273825477,
        "test_f1_micro": 0.378992193,
        "test_pearson_mean": 0.430702712
    },
    {
        "fold": 3,
        "test_loss": 0.223648310,
        "test_f1_macro": 0.257528996,
        "test_f1_micro": 0.367917586,
        "test_pearson_mean": 0.453259784
    },
    {
        "fold": 4,
        "test_loss": 0.224830836,
        "test_f1_macro": 0.202562571,
        "test_f1_micro": 0.294650206,
        "test_pearson_mean": 0.433146935
    },
    {
        "fold": 5,
        "test_loss": 0.226414382,
        "test_f1_macro": 0.299320627,
        "test_f1_micro": 0.376538740,
        "test_pearson_mean": 0.437567088
    }
]


# =========================================================
# ORIGINAL CLASSWISE RESULTS
# =========================================================

original_classwise_results = [
    {"class": "anger_1", "precision": 0.428571, "recall": 0.083333, "f1_score": 0.139535, "support": 36},
    {"class": "anger_2", "precision": 1.000000, "recall": 0.066667, "f1_score": 0.125000, "support": 15},
    {"class": "anger_3", "precision": 0.000000, "recall": 0.000000, "f1_score": 0.000000, "support": 9},

    {"class": "fear_1", "precision": 0.444444, "recall": 0.528302, "f1_score": 0.482759, "support": 159},
    {"class": "fear_2", "precision": 0.411765, "recall": 0.353535, "f1_score": 0.380435, "support": 99},
    {"class": "fear_3", "precision": 0.826087, "recall": 0.380000, "f1_score": 0.520548, "support": 50},

    {"class": "joy_1", "precision": 0.534091, "recall": 0.516484, "f1_score": 0.525140, "support": 91},
    {"class": "joy_2", "precision": 0.478261, "recall": 0.354839, "f1_score": 0.407407, "support": 31},
    {"class": "joy_3", "precision": 0.000000, "recall": 0.000000, "f1_score": 0.000000, "support": 12},

    {"class": "sadness_1", "precision": 0.432099, "recall": 0.353535, "f1_score": 0.388889, "support": 99},
    {"class": "sadness_2", "precision": 0.500000, "recall": 0.018868, "f1_score": 0.036364, "support": 53},
    {"class": "sadness_3", "precision": 0.481481, "recall": 0.590909, "f1_score": 0.530612, "support": 22},

    {"class": "surprise_1", "precision": 0.471429, "recall": 0.272727, "f1_score": 0.345550, "support": 121},
    {"class": "surprise_2", "precision": 0.625000, "recall": 0.188679, "f1_score": 0.289855, "support": 53},
    {"class": "surprise_3", "precision": 0.000000, "recall": 0.000000, "f1_score": 0.000000, "support": 6}
]


# =========================================================
# FIVE-FOLD CLASSWISE RESULTS
# =========================================================

fold_classwise_results = [

    # =========================
    # Fold 1
    # =========================
    {"fold": 1, "class": "anger_1", "precision": 0.400000000, "recall": 0.055555556, "f1_score": 0.097560976, "support": 36},
    {"fold": 1, "class": "anger_2", "precision": 1.000000000, "recall": 0.066666667, "f1_score": 0.125000000, "support": 15},
    {"fold": 1, "class": "anger_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 9},

    {"fold": 1, "class": "fear_1", "precision": 0.441666667, "recall": 0.333333333, "f1_score": 0.379928315, "support": 159},
    {"fold": 1, "class": "fear_2", "precision": 0
"support": 12},

    {"fold": 5, "class": "sadness_1", "precision": 0.515151515, "recall": 0.343434343, "f1_score": 0.412121212, "support": 99},
    {"fold": 5, "class": "sadness_2", "precision": 0.750000000, "recall": 0.056603774, "f1_score": 0.105263158, "support": 53},
    {"fold": 5, "class": "sadness_3", "precision": 0.444444444, "recall": 0.545454545, "f1_score": 0.489795918, "support": 22},

    {"fold": 5, "class": "surprise_1", "precision": 0.473684211, "recall": 0.297520661, "f1_score": 0.365482234, "support": 121},
    {"fold": 5, "class": "surprise_2", "precision": 0.785714286, "recall": 0.207547170, "f1_score": 0.328358209, "support": 53},
    {"fold": 5, "class": "surprise_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 6}
]

# =========================================================
# 5. CREATE DATAFRAMES
# =========================================================

original_overall_df = pd.DataFrame([
    {"metric": metric, "original_value": value}
    for metric, value in original_overall.items()
])

fold_overall_df = pd.DataFrame(fold_overall_results)
original_classwise_df = pd.DataFrame(original_classwise_results)
fold_classwise_df = pd.DataFrame(fold_classwise_results)


# =========================================================
# 6. VALIDATION CHECKS
# =========================================================

required_overall_metrics = [
    "test_loss",
    "test_f1_macro",
    "test_f1_micro",
    "test_pearson_mean"
]

required_classes = [
    "anger_1", "anger_2", "anger_3",
    "fear_1", "fear_2", "fear_3",
    "joy_1", "joy_2", "joy_3",
    "sadness_1", "sadness_2", "sadness_3",
    "surprise_1", "surprise_2", "surprise_3"
]

# Check overall columns
for col in ["fold"] + required_overall_metrics:
    if col not in fold_overall_df.columns:
        raise ValueError(f"Missing column in fold_overall_results: {col}")

# Check classwise columns
for col in ["class", "precision", "recall", "f1_score", "support"]:
    if col not in original_classwise_df.columns:
        raise ValueError(f"Missing column in original_classwise_results: {col}")

for col in ["fold", "class", "precision", "recall", "f1_score", "support"]:
    if col not in fold_classwise_df.columns:
        raise ValueError(f"Missing column in fold_classwise_results: {col}")

# Check number of fold overall rows
if len(fold_overall_df) != 5:
    raise ValueError("fold_overall_results must contain exactly 5 rows, one for each fold.")

# Check classes in original
missing_original_classes = set(required_classes) - set(original_classwise_df["class"])
if missing_original_classes:
    raise ValueError(f"Missing classes in original_classwise_results: {missing_original_classes}")

# Check classes in every fold
for fold in [1, 2, 3, 4, 5]:
    fold_classes = set(fold_classwise_df[fold_classwise_df["fold"] == fold]["class"])
    missing_fold_classes = set(required_classes) - fold_classes
    if missing_fold_classes:
        raise ValueError(f"Missing classes in fold {fold}: {missing_fold_classes}")


# =========================================================
# 7. OVERALL MODEL COMPARISON TABLE
# =========================================================

fold_overall_mean = fold_overall_df[required_overall_metrics].mean()
fold_overall_std = fold_overall_df[required_overall_metrics].std()

overall_comparison_table = pd.DataFrame({
    "metric": required_overall_metrics,
    "original_value": [original_overall[m] for m in required_overall_metrics],
    "cv_mean": [fold_overall_mean[m] for m in required_overall_metrics],
    "cv_std": [fold_overall_std[m] for m in required_overall_metrics]
})

overall_comparison_table["cv_mean ± std"] = (
    overall_comparison_table["cv_mean"].round(4).astype(str)
    + " ± "
    + overall_comparison_table["cv_std"].round(4).astype(str)
)


# =========================================================
# 8. CLASSWISE COMPARISON TABLE
# =========================================================

fold_classwise_mean = (
    fold_classwise_df
    .groupby("class")
    .agg(
        precision_cv_mean=("precision", "mean"),
        recall_cv_mean=("recall", "mean"),
        f1_cv_mean=("f1_score", "mean"),
        support_cv_mean=("support", "mean")
    )
    .reset_index()
)

classwise_comparison_table = original_classwise_df.merge(
    fold_classwise_mean,
    on="class",
    how="left"
)

classwise_comparison_table = classwise_comparison_table.rename(columns={
    "precision": "precision_original",
    "recall": "recall_original",
    "f1_score": "f1_original",
    "support": "support_original"
})

classwise_comparison_table = classwise_comparison_table[
    [
        "class",
        "precision_original",
        "precision_cv_mean",
        "recall_original",
        "recall_cv_mean",
        "f1_original",
        "f1_cv_mean",
        "support_original",
        "support_cv_mean"
    ]
]


# =========================================================
# 9. ROUND VALUES FOR DISPLAY
# =========================================================

overall_comparison_table_display = overall_comparison_table.copy()
for col in ["original_value", "cv_mean", "cv_std"]:
    overall_comparison_table_display[col] = overall_comparison_table_display[col].round(4)

classwise_comparison_table_display = classwise_comparison_table.copy()
for col in [
    "precision_original",
    "precision_cv_mean",
    "recall_original",
    "recall_cv_mean",
    "f1_original",
    "f1_cv_mean",
    "support_cv_mean"
]:
    classwise_comparison_table_display[col] = classwise_comparison_table_display[col].round(4)


# =========================================================
# 10. DISPLAY ONLY TWO TABLES
# =========================================================
print("Results for RoBERTa (8,8) single step approach with 5-fold cross validation on the test set.")
print("OVERALL MODEL COMPARISON")
display(overall_comparison_table_display)

print("CLASSWISE COMPARISON")
display(classwise_comparison_table_display)
# Out:
# Results for RoBERTa (8,8) single step approach with 5-fold cross validation on the test set.
# OVERALL MODEL COMPARISON
#               metric  original_value  cv_mean  cv_std    cv_mean ± std
# 0          test_loss          0.2287   0.2254  0.0018  0.2254 ± 0.0018
# 1      test_f1_macro          0.2781   0.2538  0.0369  0.2538 ± 0.0369
# 2      test_f1_micro          0.3978   0.3561  0.0350   0.3561 ± 0.035
# 3  test_pearson_mean          0.4375   0.4369  0.0096  0.4369 ± 0.0096
# CLASSWISE COMPARISON
#          class  precision_original  precision_cv_mean  recall_original  \
# 0      anger_1              0.4286             0.2633           0.0833
# 1      anger_2              1.0000             0.7333           0.0667
# 2      anger_3              0.0000             0.0000           0.0000
# 3       fear_1              0.4444             0.4486           0.5283
# 4       fear_2              0.4118             0.4404           0.3535
# ...

# %%
# =========================================================
# FINAL MANUAL ANALYSIS CODE
# Original Model vs 5-Fold Cross Validation
# Outputs ONLY TWO TABLES
# =========================================================

import pandas as pd
import numpy as np

# =========================================================
# ORIGINAL OVERALL RESULTS
# =========================================================

original_overall = {
    "test_loss": 0.230523,
    "test_f1_macro": 0.228763,
    "test_f1_micro": 0.350649,
    "test_pearson_mean": 0.428407
}


# =========================================================
# FIVE-FOLD OVERALL RESULTS
# =========================================================

fold_overall_results = [
    {
        "fold": 1,
        "test_loss": 0.226764962,
        "test_f1_macro": 0.234846616,
        "test_f1_micro": 0.333333333,
        "test_pearson_mean": 0.425575278
    },
    {
        "fold": 2,
        "test_loss": 0.228837654,
        "test_f1_macro": 0.227329760,
        "test_f1_micro": 0.337878788,
        "test_pearson_mean": 0.423977779
    },
    {
        "fold": 3,
        "test_loss": 0.229613453,
        "test_f1_macro": 0.270962948,
        "test_f1_micro": 0.370153621,
        "test_pearson_mean": 0.427293280
    },
    {
        "fold": 4,
        "test_loss": 0.228469685,
        "test_f1_macro": 0.279941688,
        "test_f1_micro": 0.389392882,
        "test_pearson_mean": 0.443071706
    },
    {
        "fold": 5,
        "test_loss": 0.222338140,
        "test_f1_macro": 0.263512983,
        "test_f1_micro": 0.355154251,
        "test_pearson_mean": 0.449559626
    }
]


# =========================================================
# ORIGINAL CLASSWISE RESULTS
# =========================================================

original_classwise_results = [
    {"class": "anger_1", "precision": 0.333333, "recall": 0.027778, "f1_score": 0.051282, "support": 36},
    {"class": "anger_2", "precision": 1.000000, "recall": 0.066667, "f1_score": 0.125000, "support": 15},
    {"class": "anger_3", "precision": 0.000000, "recall": 0.000000, "f1_score": 0.000000, "support": 9},

    {"class": "fear_1", "precision": 0.407583, "recall": 0.540881, "f1_score": 0.464865, "support": 159},
    {"class": "fear_2", "precision": 0.345455, "recall": 0.191919, "f1_score": 0.246753, "support": 99},
    {"class": "fear_3", "precision": 0.761905, "recall": 0.320000, "f1_score": 0.450704, "support": 50},

    {"class": "joy_1", "precision": 0.600000, "recall": 0.461538, "f1_score": 0.521739, "support": 91},
    {"class": "joy_2", "precision": 0.357143, "recall": 0.161290, "f1_score": 0.222222, "support": 31},
    {"class": "joy_3", "precision": 0.000000, "recall": 0.000000, "f1_score": 0.000000, "support": 12},

    {"class": "sadness_1", "precision": 0.410256, "recall": 0.161616, "f1_score": 0.231884, "support": 99},
    {"class": "sadness_2", "precision": 0.000000, "recall": 0.000000, "f1_score": 0.000000, "support": 53},
    {"class": "sadness_3", "precision": 0.550000, "recall": 0.500000, "f1_score": 0.523810, "support": 22},

    {"class": "surprise_1", "precision": 0.475610, "recall": 0.322314, "f1_score": 0.384236, "support": 121},
    {"class": "surprise_2", "precision": 0.500000, "recall": 0.132075, "f1_score": 0.208955, "support": 53},
    {"class": "surprise_3", "precision": 0.000000, "recall": 0.000000, "f1_score": 0.000000, "support": 6}
]


# =========================================================
# FIVE-FOLD CLASSWISE RESULTS
# =========================================================

fold_classwise_results = [

    # =========================
    # Fold 1
    # =========================
    {"fold": 1, "class": "anger_1", "precision": 0.200000000, "recall": 0.027777778, "f1_score": 0.048780488, "support": 36},
    {"fold": 1, "class": "anger_2", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 15},
    {"fold": 1, "class": "anger_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 9},

    {"fold": 1, "class": "fear_1", "precision": 0.500000000, "recall": 0.232704403, "f1_score": 0.317596567, "support": 159},
    {"fold": 1, "class": "fear_2", "precision": 0.415384615, "recall": 0.272727273, "f1_score": 0.329268293, "support": 99},
    {"fold": 1, "class": "fear_3", "precision": 0.559322034, "recall": 0.660000000, "f1_score": 0.605504587, "support": 50},

    {"fold": 1, "class": "joy_1", "precision": 0.586206897, "recall": 0.373626374, "f1_score": 0.456375839, "support": 91},
    {"fold": 1, "class": "joy_2", "precision": 0.437500000, "recall": 0.225806452, "f1_score": 0.297872340, "support": 31},
    {"fold": 1, "class": "joy_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 12},

    {"fold": 1, "class": "sadness_1", "precision": 0.558139535, "recall": 0.242424242, "f1_score": 0.338028169, "support": 99},
    {"fold": 1, "class": "sadness_2", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 53},
    {"fold": 1, "class": "sadness_3", "precision": 0.550000000, "recall": 0.500000000, "f1_score": 0.523809524, "support": 22},

    {"fold": 1, "class": "surprise_1", "precision": 0.520000000, "recall": 0.214876033, "f1_score": 0.304093567, "support": 121},
    {"fold": 1, "class": "surprise_2", "precision": 0.550000000, "recall": 0.207547170, "f1_score": 0.301369863, "support": 53},
    {"fold": 1, "class": "surprise_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 6},


    # =========================
    # Fold 2
    # =========================
    {"fold": 2, "class": "anger_1", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 36},
    {"fold": 2, "class": "anger_2", "precision": 1.000000000, "recall": 0.066666667, "f1_score": 0.125000000, "support": 15},
    {"fold": 2, "class": "anger_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 9},

    {"fold": 2, "class": "fear_1", "precision": 0.453488372, "recall": 0.490566038, "f1_score": 0.471299094, "support": 159},
    {"fold": 2, "class": "fear_2", "precision": 0.327586207, "recall": 0.191919192, "f1_score": 0.242038217, "support": 99},
    {"fold": 2, "class": "fear_3", "precision": 0.733333333, "recall": 0.440000000, "f1_score": 0.550000000, "support": 50},

    {"fold": 2, "class": "joy_1", "precision": 0.546875000, "recall": 0.384615385, "f1_score": 0.451612903, "support": 91},
    {"fold": 2, "class": "joy_2", "precision": 0.500000000, "recall": 0.161290323, "f1_score": 0.243902439, "support": 31},
    {"fold": 2, "class": "joy_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 12},

    {"fold": 2, "class": "sadness_1", "precision": 0.520833333, "recall": 0.252525253, "f1_score": 0.340136054, "support": 99},
    {"fold": 2, "class": "sadness_2", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 53},
    {"fold": 2, "class": "sadness_3", "precision": 0.500000000, "recall": 0.636363636, "f1_score": 0.560000000, "support": 22},

    {"fold": 2, "class": "surprise_1", "precision": 0.447368421, "recall": 0.140495868, "f1_score": 0.213836478, "support": 121},
    {"fold": 2, "class": "surprise_2", "precision": 0.538461538, "recall": 0.132075472, "f1_score": 0.212121212, "support": 53},
    {"fold": 2, "class": "surprise_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 6},


    # =========================
    # Fold 3
    # =========================
    {"fold": 3, "class": "anger_1", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 36},
    {"fold": 3, "class": "anger_2", "precision": 1.000000000, "recall": 0.066666667, "f1_score": 0.125000000, "support": 15},
    {"fold": 3, "class": "anger_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 9},

    {"fold": 3, "class": "fear_1", "precision": 0.428571429, "recall": 0.264150943, "f1_score": 0.326848249, "support": 159},
    {"fold": 3, "class": "fear_2", "precision": 0.428571429, "recall": 0.272727273, "f1_score": 0.333333333, "support": 99},
    {"fold": 3, "class": "fear_3", "precision": 0.611111111, "recall": 0.440000000, "f1_score": 0.511627907, "support": 50},

    {"fold": 3, "class": "joy_1", "precision": 0.580246914, "recall": 0.516483516, "f1_score": 0.546511628, "support": 91},
    {"fold": 3, "class": "joy_2", "precision": 0.571428571, "recall": 0.387096774, "f1_score": 0.461538462, "support": 31},
    {"fold": 3, "class": "joy_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 12},

    {"fold": 3, "class": "sadness_1", "precision": 0.448275862, "recall": 0.262626263, "f1_score": 0.331210191, "support": 99},
    {"fold": 3, "class": "sadness_2", "precision": 1.000000000, "recall": 0.037735849, "f1_score": 0.072727273, "support": 53},
    {"fold": 3, "class": "sadness_3", "precision": 0.437500000, "recall": 0.636363636, "f1_score": 0.518518519, "support": 22},

    {"fold": 3, "class": "surprise_1", "precision": 0.466666667, "recall": 0.347107438, "f1_score": 0.398104265, "support": 121},
    {"fold": 3, "class": "surprise_2", "precision": 0.620689655, "recall": 0.339622642, "f1_score": 0.439024390, "support": 53},
    {"fold": 3, "class": "surprise_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 6},


    # =========================
    # Fold 4
    # =========================
    {"fold": 4, "class": "anger_1", "precision": 0.333333333, "recall": 0.027777778, "f1_score": 0.051282051, "support": 36},
    {"fold": 4, "class": "anger_2", "precision": 0.600000000, "recall": 0.200000000, "f1_score": 0.300000000, "support": 15},
    {"fold": 4, "class": "anger_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 9},

    {"fold": 4, "class": "fear_1", "precision": 0.432926829, "recall": 0.446540881, "f1_score": 0.439628483, "support": 159},
    {"fold": 4, "class": "fear_2", "precision": 0.389380531, "recall": 0.444444444, "f1_score": 0.415094340, "support": 99},
    {"fold": 4, "class": "fear_3", "precision": 0.750000000, "recall": 0.420000000, "f1_score": 0.538461538, "support": 50},

    {"fold": 4, "class": "joy_1", "precision": 0.684210526, "recall": 0.285714286, "f1_score": 0.403100775, "support": 91},
    {"fold": 4, "class": "joy_2", "precision": 0.454545455, "recall": 0.161290323, "f1_score": 0.238095238, "support": 31},
    {"fold": 4, "class": "joy_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 12},

    {"fold": 4, "class": "sadness_1", "precision": 0.509803922, "recall": 0.262626263, "f1_score": 0.346666667, "support": 99},
    {"fold": 4, "class": "sadness_2", "precision": 0.333333333, "recall": 0.037735849, "f1_score": 0.067796610, "support": 53},
    {"fold": 4, "class": "sadness_3", "precision": 0.642857143, "recall": 0.409090909, "f1_score": 0.500000000, "support": 22},

    {"fold": 4, "class": "surprise_1", "precision": 0.476190476, "recall": 0.413223140, "f1_score": 0.442477876, "support": 121},
    {"fold": 4, "class": "surprise_2", "precision": 0.538461538, "recall": 0.396226415, "f1_score": 0.456521739, "support": 53},
    {"fold": 4, "class": "surprise_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 6},


    # =========================
    # Fold 5
    # =========================
    {"fold": 5, "class": "anger_1", "precision": 0.333333333, "recall": 0.083333333, "f1_score": 0.133333333, "support": 36},
    {"fold": 5, "class": "anger_2", "precision": 0.250000000, "recall": 0.066666667, "f1_score": 0.105263158, "support": 15},
    {"fold": 5, "class": "anger_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 9},

    {"fold": 5, "class": "fear_1", "precision": 0.421052632, "recall": 0.402515723, "f1_score": 0.411575563, "support": 159},
    {"fold": 5, "class": "fear_2", "precision": 0.419354839, "recall": 0.262626263, "f1_score": 0.322981366, "support": 99},
    {"fold": 5, "class": "fear_3", "precision": 0.724137931, "recall": 0.420000000, "f1_score": 0.531645570, "support": 50},

    {"fold": 5, "class": "joy_1", "precision": 0.682926829, "recall": 0.307692308, "f1_score": 0.424242424, "support": 91},
    {"fold": 5, "class": "joy_2", "precision": 0.615384615, "recall": 0.258064516, "f1_score": 0.363636364, "support": 31},
    {"fold": 5, "class": "joy_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 12},

    {"fold": 5, "class": "sadness_1", "precision": 0.473684211, "recall": 0.090909091, "f1_score": 0.152542373, "support": 99},
    {"fold": 5, "class": "sadness_2", "precision": 0.750000000, "recall": 0.056603774, "f1_score": 0.105263158, "support": 53},
    {"fold": 5, "class": "sadness_3", "precision": 0.611111111, "recall": 0.500000000, "f1_score": 0.550000000, "support": 22},

    {"fold": 5, "class": "surprise_1", "precision": 0.494117647, "recall": 0.347107438, "f1_score": 0.407766990, "support": 121},
    {"fold": 5, "class": "surprise_2", "precision": 0.540540541, "recall": 0.377358491, "f1_score": 0.444444444, "support": 53},
    {"fold": 5, "class": "surprise_3", "precision": 0.000000000, "recall": 0.000000000, "f1_score": 0.000000000, "support": 6}
]

# =========================================================
# 5. CREATE DATAFRAMES
# =========================================================

original_overall_df = pd.DataFrame([
    {"metric": metric, "original_value": value}
    for metric, value in original_overall.items()
])

fold_overall_df = pd.DataFrame(fold_overall_results)
original_classwise_df = pd.DataFrame(original_classwise_results)
fold_classwise_df = pd.DataFrame(fold_classwise_results)


# =========================================================
# 6. VALIDATION CHECKS
# =========================================================

required_overall_metrics = [
    "test_loss",
    "test_f1_macro",
    "test_f1_micro",
    "test_pearson_mean"
]

required_classes = [
    "anger_1", "anger_2", "anger_3",
    "fear_1", "fear_2", "fear_3",
    "joy_1", "joy_2", "joy_3",
    "sadness_1", "sadness_2", "sadness_3",
    "surprise_1", "surprise_2", "surprise_3"
]

# Check overall columns
for col in ["fold"] + required_overall_metrics:
    if col not in fold_overall_df.columns:
        raise ValueError(f"Missing column in fold_overall_results: {col}")

# Check classwise columns
for col in ["class", "precision", "recall", "f1_score", "support"]:
    if col not in original_classwise_df.columns:
        raise ValueError(f"Missing column in original_classwise_results: {col}")

for col in ["fold", "class", "precision", "recall", "f1_score", "support"]:
    if col not in fold_classwise_df.columns:
        raise ValueError(f"Missing column in fold_classwise_results: {col}")

# Check number of fold overall rows
if len(fold_overall_df) != 5:
    raise ValueError("fold_overall_results must contain exactly 5 rows, one for each fold.")

# Check classes in original
missing_original_classes = set(required_classes) - set(original_classwise_df["class"])
if missing_original_classes:
    raise ValueError(f"Missing classes in original_classwise_results: {missing_original_classes}")

# Check classes in every fold
for fold in [1, 2, 3, 4, 5]:
    fold_classes = set(fold_classwise_df[fold_classwise_df["fold"] == fold]["class"])
    missing_fold_classes = set(required_classes) - fold_classes
    if missing_fold_classes:
        raise ValueError(f"Missing classes in fold {fold}: {missing_fold_classes}")


# =========================================================
# 7. OVERALL MODEL COMPARISON TABLE
# =========================================================

fold_overall_mean = fold_overall_df[required_overall_metrics].mean()
fold_overall_std = fold_overall_df[required_overall_metrics].std()

overall_comparison_table = pd.DataFrame({
    "metric": required_overall_metrics,
    "original_value": [original_overall[m] for m in required_overall_metrics],
    "cv_mean": [fold_overall_mean[m] for m in required_overall_metrics],
    "cv_std": [fold_overall_std[m] for m in required_overall_metrics]
})

overall_comparison_table["cv_mean ± std"] = (
    overall_comparison_table["cv_mean"].round(4).astype(str)
    + " ± "
    + overall_comparison_table["cv_std"].round(4).astype(str)
)


# =========================================================
# 8. CLASSWISE COMPARISON TABLE
# =========================================================

fold_classwise_mean = (
    fold_classwise_df
    .groupby("class")
    .agg(
        precision_cv_mean=("precision", "mean"),
        recall_cv_mean=("recall", "mean"),
        f1_cv_mean=("f1_score", "mean"),
        support_cv_mean=("support", "mean")
    )
    .reset_index()
)

classwise_comparison_table = original_classwise_df.merge(
    fold_classwise_mean,
    on="class",
    how="left"
)

classwise_comparison_table = classwise_comparison_table.rename(columns={
    "precision": "precision_original",
    "recall": "recall_original",
    "f1_score": "f1_original",
    "support": "support_original"
})

classwise_comparison_table = classwise_comparison_table[
    [
        "class",
        "precision_original",
        "precision_cv_mean",
        "recall_original",
        "recall_cv_mean",
        "f1_original",
        "f1_cv_mean",
        "support_original",
        "support_cv_mean"
    ]
]


# =========================================================
# 9. ROUND VALUES FOR DISPLAY
# =========================================================

overall_comparison_table_display = overall_comparison_table.copy()
for col in ["original_value", "cv_mean", "cv_std"]:
    overall_comparison_table_display[col] = overall_comparison_table_display[col].round(4)

classwise_comparison_table_display = classwise_comparison_table.copy()
for col in [
    "precision_original",
    "precision_cv_mean",
    "recall_original",
    "recall_cv_mean",
    "f1_original",
    "f1_cv_mean",
    "support_cv_mean"
]:
    classwise_comparison_table_display[col] = classwise_comparison_table_display[col].round(4)


# =========================================================
# 10. DISPLAY ONLY TWO TABLES
# =========================================================
print("Results for RoBERTa (16,16) single step approach with 5-fold cross validation on the test set.")
print("OVERALL MODEL COMPARISON")
display(overall_comparison_table_display)

print("CLASSWISE COMPARISON")
display(classwise_comparison_table_display)
# Out:
# Results for RoBERTa (16,16) single step approach with 5-fold cross validation on the test set.
# OVERALL MODEL COMPARISON
#               metric  original_value  cv_mean  cv_std    cv_mean ± std
# 0          test_loss          0.2305   0.2272  0.0029  0.2272 ± 0.0029
# 1      test_f1_macro          0.2288   0.2553  0.0230   0.2553 ± 0.023
# 2      test_f1_micro          0.3506   0.3572  0.0232  0.3572 ± 0.0232
# 3  test_pearson_mean          0.4284   0.4339  0.0116  0.4339 ± 0.0116
# CLASSWISE COMPARISON
#          class  precision_original  precision_cv_mean  recall_original  \
# 0      anger_1              0.3333             0.1733           0.0278
# 1      anger_2              1.0000             0.5700           0.0667
# 2      anger_3              0.0000             0.0000           0.0000
# 3       fear_1              0.4076             0.4472           0.5409
# 4       fear_2              0.3455             0.3961           0.1919
# ...

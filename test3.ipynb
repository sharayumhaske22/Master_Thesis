# %%
TOKEN = "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"
USERNAME = "sharayumhaske22"
REPO = "Master_Thesis"

# !git clone https://{USERNAME}:{TOKEN}@github.com/{USERNAME}/{REPO}.git

# %%
# %cd /content/Master_Thesis
# !git pull

# !ls /content
# Out:
# /content/Master_Thesis
# Already up to date.
# Master_Thesis			  RoBERTa_Log.csv	     sample_data
# roberta_brighter_onlyintensities  roberta_loss_accuracy.csv

# %%
# !rm /content/RoBERTa_Log.csv
# !ls /content
# Out:
# rm: cannot remove '/content/RoBERTa_Log.csv': No such file or directory
# Master_Thesis			  roberta_loss_accuracy.csv
# roberta_brighter_onlyintensities  sample_data

# %%
# !rm /content/roberta_brighter_onlyintensities
# !rm /content/roberta_loss_accuracy.csv
# !ls /content
# Out:
# rm: cannot remove '/content/roberta_brighter_onlyintensities': Is a directory
# Master_Thesis  roberta_brighter_onlyintensities  sample_data

# %%
# !rm -rf /content/roberta_brighter_onlyintensities
# !ls /content
# Out:
# Master_Thesis  sample_data

# %%
# !ls "/content/Master_Thesis"
# Out:
# DistilBERT.ipynb	RoBERTa_Hierarchical.ipynb  test2.ipynb
# emotion_intensity_data	RoBERTa.ipynb		    test3.ipynb
# log_files		RoBERTa_SingleStep.ipynb    test.ipynb
